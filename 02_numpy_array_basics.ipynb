# %% [markdown]
# # NumPy Array Basics
#
# ## Objective
#
# Learn how to create NumPy arrays and understand their fundamental properties.

# %%
#one rule here is the 2d array both must braced have same number of elements   
# and again in shape 2 is row and 3 is coloumn 
import numpy as np
arr = np.array([[1,2,3] , [4,5,6]])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr.shape
# Out:
# (2, 3)

# %%
arr.ndim
# Out:
# 2

# %%
arr.size
# Out:
# 6

# %%
arr.dtype
# Out:
# dtype('int64')
